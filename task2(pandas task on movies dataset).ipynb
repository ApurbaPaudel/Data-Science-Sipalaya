# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\movies.csv")
df
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 4                                 Joker           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         Kumonosu-jô           1957      110   Drama
# 296                        Falling Down           1993      113  Action
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
# 299                         Kai po che!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...

# %% [markdown]
# ### 1.Find the most common star(actor) in the dataset.

# %%
df['Star1'].value_counts()
# Out:
# Star1
# Johnny Depp          6
# Humphrey Bogart      5
# Christian Bale       5
# Leonardo DiCaprio    5
# Al Pacino            4
#                     ..
# Marlon Brando        1
# Seung-Yun Lee        1
# Michael Douglas      1
# Gene Hackman         1
# Amit Sadh            1
# Name: count, Length: 238, dtype: int64

# %%
df['Star1'].value_counts().idxmax()
# Out:
# 'Johnny Depp'

# %% [markdown]
# ### 2.List all movies that have both an IMDB rating greater than 7 and a metascore greater than 70.

# %%
df[(df['IMDB_Rating']>7) & (df['Metascore']>70)]
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 6                      Edge of Tomorrow           2014      113  Action
# ..                                  ...            ...      ...     ...
# 292                       The Godfather           1972      175   Crime
# 293                   Road to Perdition           2002      117   Crime
# 294                             Bin-jip           2004       88   Crime
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
#
#      IMDB_Rating              Director             Star1  No_of_Votes  \
# ...

# %% [markdown]
# ### 3.Find all movies directed by a specific director.

# %%
df[df['Director']=='Steven Spielberg']
# Out:
#                            Series_Title  Released_Year  Runtime      Genre  \
# 3    Close Encounters of the Third Kind           1977      138      Drama
# 121                 Catch Me If You Can           2002      141  Biography
#
#      IMDB_Rating          Director              Star1  No_of_Votes  \
# 3            7.6  Steven Spielberg   Richard Dreyfuss       184966
# 121          8.1  Steven Spielberg  Leonardo DiCaprio       832846
#
#            Gross  Metascore
# 3    132088635.0       90.0
# 121  164615351.0       75.0

# %% [markdown]
# ### 4. Get the average gross revenue per genre.

# %%
df.groupby('Genre')['Gross'].mean()
# Out:
# Genre
# Action       1.842691e+08
# Adventure    1.034306e+08
# Animation    1.832695e+08
# Biography    1.182193e+08
# Comedy       7.305349e+07
# Crime        8.424648e+07
# Drama        1.013609e+08
# Fantasy      3.375747e+08
# Film-Noir    4.491910e+05
# Horror       2.930818e+07
# Mystery      1.437833e+07
# Western      5.321508e+06
# Name: Gross, dtype: float64

# %% [markdown]
# ### 5.Find the top 10 highest grossing movies.

# %%
df['Gross'].value_counts().head(10)
# Out:
# Gross
# 1122527.0      1
# 29000000.0     1
# 102515793.0    1
# 1221261.0      1
# 132088635.0    1
# 335451311.0    1
# 213351844.0    1
# 100206256.0    1
# 26400640.0     1
# 574305769.0    1
# Name: count, dtype: int64

# %% [markdown]
# ### 6.Get the average IMDB rating of all movies in the dataset.

# %%
df['IMDB_Rating'].mean()
# Out:
# np.float64(7.963333333333333)

# %%
float(df['IMDB_Rating'].mean())
# Out:
# 7.963333333333333

# %% [markdown]
# ### 7.Get movies released after 2010.

# %%
df[df['Released_Year']>2010]
# Out:
#                          Series_Title  Released_Year  Runtime      Genre  \
# 1     The Girl with the Dragon Tattoo           2011      158      Crime
# 4                               Joker           2019      122      Crime
# 6                    Edge of Tomorrow           2014      113     Action
# 8                               Pride           2014      119  Biography
# 16       Kingsman: The Secret Service           2014      129     Action
# ..                                ...            ...      ...        ...
# 280                          Hamilton           2020      160  Biography
# 281                    Only the Brave           2017      134     Action
# 286  Once Upon a Time... in Hollywood           2019      161     Comedy
# 291                        Deadpool 2           2018      119     Action
# 299                       Kai po che!           2013      130      Drama
#
#      IMDB_Rating           Director               Star1  No_of_Votes  \
# ...

# %% [markdown]
# ### 8.Get a list of unique genres in the dataset.

# %%
list(df['Genre'].unique())
# Out:
# ['Drama',
#  'Crime',
#  'Action',
#  'Biography',
#  'Comedy',
#  'Adventure',
#  'Film-Noir',
#  'Animation',
#  'Horror',
#  'Mystery',
#  'Fantasy',
#  'Western']

# %% [markdown]
# ### 9.Get the number of movies in the dataset.

# %%
len(df['Series_Title'])
# Out:
# 300

# %% [markdown]
# ### 10.Display the movies from the index position 100 to 200 using iloc methods.

# %%
df.iloc[100:201]
# Out:
#                    Series_Title  Released_Year  Runtime      Genre  \
# 100                      Avatar           2009      162     Action
# 101            A Beautiful Mind           2001      135  Biography
# 102    The Last of the Mohicans           1992      112     Action
# 103           Dog Day Afternoon           1975      125  Biography
# 104  Terminator 2: Judgment Day           1991      137     Action
# ..                          ...            ...      ...        ...
# 196                Delicatessen           1991       99     Comedy
# 197             Kurenai no buta           1992       94  Animation
# 198              La vie d'Adèle           2013      180      Drama
# 199              Loving Vincent           2017       94  Animation
# 200               Casino Royale           2006      144     Action
#
#      IMDB_Rating             Director                  Star1  No_of_Votes  \
# 100          7.8        James Cameron        Sam Worthington      1118998
# ...

# %% [markdown]
# ### 11.Find the average gross for movies directed by a specific director,with an IMDB rating above 7.

# %%
float(df[(df['Director']=='Christopher Nolan') & (df['IMDB_Rating']>7)]['Gross'].mean())
# Out:
# 345362478.0

# %% [markdown]
# ### 12.Find the oldest movie in terms of release year with an IMDB rating greater than 8.

# %%
df[(df['IMDB_Rating']>8)].sort_values('Released_Year').head(1)
# Out:
#                      Series_Title  Released_Year  Runtime    Genre  \
# 115  Das Cabinet des Dr. Caligari           1920       76  Fantasy
#
#      IMDB_Rating      Director          Star1  No_of_Votes        Gross  \
# 115          8.1  Robert Wiene  Werner Krauss        57428  337574718.0
#
#      Metascore
# 115        NaN

# %% [markdown]
# ### 13.Get the correlation between gross and metascore in the dataset.

# %%
gross = df['Gross']
metascore = df['Metascore']
float(gross.corr(metascore))
# Out:
# 0.04785956965625054

# %% [markdown]
# ### 14.Find the top 5 stars who have appeared in the most movies.

# %%
df['Star1'].value_counts().head()
# Out:
# Star1
# Johnny Depp          6
# Humphrey Bogart      5
# Christian Bale       5
# Leonardo DiCaprio    5
# Al Pacino            4
# Name: count, dtype: int64

# %% [markdown]
# ### 15.Get the average gross for movies with different genres, but only for movies with IMDB ratings greater than 7.

# %%
fdf=df[df['IMDB_Rating']>7]
fdf
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 4                                 Joker           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         Kumonosu-jô           1957      110   Drama
# 296                        Falling Down           1993      113  Action
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
# 299                         Kai po che!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...

# %%
avg_gross=fdf.groupby('Genre')['Gross'].mean()
print(avg_gross)
# Out:
# Genre
# Action       1.842691e+08
# Adventure    1.034306e+08
# Animation    1.832695e+08
# Biography    1.182193e+08
# Comedy       7.305349e+07
# Crime        8.424648e+07
# Drama        1.013609e+08
# Fantasy      3.375747e+08
# Film-Noir    4.491910e+05
# Horror       2.930818e+07
# Mystery      1.437833e+07
# Western      5.321508e+06
# Name: Gross, dtype: float64

# %% [markdown]
# ### 16.Find all movies with a metascore higher tham 90 and released after 2015.

# %%
df[(df['Metascore']>90) & (df['Released_Year']>2015)]
# Out:
#        Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 55       La La Land           2016      128  Comedy          8.0
# 91   Manbiki kazoku           2018      121   Crime          7.9
# 136            Roma           2018      135   Drama          7.7
# 278  Marriage Story           2019      137  Comedy          7.9
#
#              Director             Star1  No_of_Votes        Gross  Metascore
# 55    Damien Chazelle      Ryan Gosling       505918  151101803.0       94.0
# 91   Hirokazu Koreeda       Lily Franky        62754    3313513.0       93.0
# 136    Alfonso Cuarón  Yalitza Aparicio       140375  557873261.0       96.0
# 278     Noah Baumbach       Adam Driver       246644    2000000.0       94.0

# %% [markdown]
# ### 17.Get the number of movies with an IMDB rating greater than 8 for each genre.

# %%
fil_df=df[df['IMDB_Rating']>8]

# %%
movie_count=fil_df.groupby('Genre')['IMDB_Rating'].count()
print(movie_count)
# Out:
# Genre
# Action       15
# Adventure     5
# Animation    10
# Biography    10
# Comedy        9
# Crime        21
# Drama        31
# Fantasy       1
# Film-Noir     1
# Western       1
# Name: IMDB_Rating, dtype: int64

# %% [markdown]
# ### 18.Find the highest grossing movie for each year.

# %%
highest_grossing_movies = df.loc[df.groupby('Released_Year')['Gross'].idxmax()]

print(highest_grossing_movies[['Released_Year', 'Series_Title', 'Gross']])
# Out:
#      Released_Year                       Series_Title        Gross
# 115           1920       Das Cabinet des Dr. Caligari  337574718.0
# 148           1928                         The Circus  259701815.0
# 122           1931  M - Eine Stadt sucht einen Mörder      28877.0
# 80            1932  Scarface: The Shame of the Nation   82900837.0
# 132           1934                       The Thin Man   40687532.0
# ..             ...                                ...          ...
# 20            2016                          Rogue One  532177324.0
# 51            2017                     Thor: Ragnarok  315058289.0
# 150           2018                              Raazi  896910257.0
# 251           2019                  Avengers: Endgame  858373000.0
# 280           2020                           Hamilton  440984783.0
#
# [81 rows x 3 columns]

# %% [markdown]
# ### 19.Get the average IMDB rating for each director.

# %%
avg_rating=df.groupby('Director')['IMDB_Rating'].mean()
print(avg_rating)
# Out:
# Director
# Aamir Khan             8.40
# Abdellatif Kechiche    7.70
# Abhishek Kapoor        7.70
# Adam McKay             7.80
# Aditya Dhar            8.20
#                        ...
# Yash Chopra            7.80
# Yasujirô Ozu           8.20
# Yimou Zhang            8.10
# Yoshiaki Kawajiri      7.70
# Zoya Akhtar            8.05
# Name: IMDB_Rating, Length: 222, dtype: float64
