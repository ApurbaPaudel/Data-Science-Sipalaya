# %%
# Data Extraction (dtabase , web scrapings ,Api ) --> cleaning cleaning( remove null data , ) 
# analysis (Exploratrory data anaysis ) -->: preprocessingv  --> algorithm applt

# %%
Bivariate Analysis
numerical vs numerical
Use case - Finding correlation

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
experience=[10,20,30,40,50]
salary=[10000,15000,20000,430000,340000]

# %%
plt.scatter(experience,salary)
plt.show()

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\batter.csv")

# %%
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
plt.scatter(df['avg'],df['strike_rate'],color='red',marker='+')

plt.title('Avg and SR analysis of Top 50 Batsman')
plt.xlabel('Average')
plt.ylabel('SR')
plt.show()

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### total bill and tip relation

# %%
plt.scatter(tips['tip'],tips['total_bill'],color='green',alpha=0.8) #alpha=opacity
plt.title('Total bill vs Tip')
plt.xlabel('tips')
plt.ylabel('total Bill')
plt.show()

# %%
tips['tip'].nlargest(5)
# Out:
# 170    10.00
# 212     9.00
# 23      7.58
# 59      6.73
# 141     6.70
# Name: tip, dtype: float64

# %%
tips['tip'].nlargest(10).values
# Out:
# array([10.  ,  9.  ,  7.58,  6.73,  6.7 ,  6.5 ,  6.5 ,  6.  ,  5.92,
#         5.85])

# %%
tips['tip'].nlargest(10).index
# Out:
# Index([170, 212, 23, 59, 141, 183, 214, 47, 239, 88], dtype='int64')

# %%
tips.iloc[3] # index 3 ko info dinxa
# Out:
# total_bill     23.68
# tip             3.31
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 3, dtype: object

# %%
hig=tips.iloc[tips['tip'].nlargest(10).index]

# %%
hig
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2

# %%
plt.scatter(hig['tip'],hig['total_bill'])

# %%
plt.scatter(hig['tip'],hig['total_bill'],s=hig['size']*100) #s= le sano size ko ko dot sano

# %%
size=hig['size'].tolist()

# %%
tip=hig['tip'].tolist()

# %%
total=hig['total_bill'].tolist()
len(total)
# Out:
# 10

# %%
plt.scatter(hig['tip'],hig['total_bill'],s=hig['size']*100)
for i in range(len(total)):
    plt.text(tip[i],total[i],size[i])

# %% [markdown]
# ## Barplots

# %%
# simple bar chart
children = [10,20,40,10,30]
colors = ['red','blue','green','yellow','pink']

plt.bar(colors,children,color='black')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(colors,children,color=['red','blue','green','yellow','pink'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(colors,children,color=['red','blue','green','yellow','pink']) #horizontal
# Out:
# <BarContainer object of 5 artists>

# %%
children = [10,20,40,10,30]
colors = ['red red red red red red','blue blue blue blue','green green green green green','yellow yellow yellow yellow ','pink pinkpinkpink']

plt.bar(colors,children,color='black',align ='edge') #edge le category label edge bata start
plt.xticks(rotation='vertical')
plt.xticks(rotation=90)
plt.show() # unnecessary detail dehaunna

# %%
children = [10,20,40,10,30]
colors = ['red red red red red red','blue blue blue blue','green green green green green','yellow yellow yellow yellow ','pink pinkpinkpink']

plt.bar(colors,children,color='black',width=0.3) 
plt.xticks(rotation='vertical')
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data

values = [10, 15, 7, 12]
x_ticks = [10,11,12,13]  # Custom positions for the x-axis ticks
x_labels = ['A', 'B', 'C', 'D']  # Custom labels for each category
bars=plt.bar(x_ticks,values)
plt.xticks(ticks=x_ticks,labels=x_labels)
plt.bar(x_ticks,values)
# Out:
# <BarContainer object of 4 artists>

# %%
values = [10, 15, 7, 12]
x_ticks = [10,11,12,13]  # Custom positions for the x-axis ticks
x_labels = ['A', 'B', 'C', 'D']  # Custom labels for each category
bars=plt.bar(x_ticks,values)
plt.xticks(ticks=x_ticks,labels=x_labels)

for i in range (len(x_labels)):
    plt.text(x_ticks[i],values[i],str(x_labels[i]+' : '+str(values[i])),rotation=45,fontweight='bold')
plt.bar(x_ticks,values,color='purple')
# Out:
# <BarContainer object of 4 artists>

# %% [raw]
# Univariate/Bivariate Analysis
# Categorical vs numerical
# Use case - To find contibution on a standard scale

# %%
data = [23,45,100,20,49]

subjects = ['eng','science','maths','sst','nepali']

explode=[0.01,0.2,0,0.2,0.3]



plt.pie(data,labels=subjects,autopct='%0.1f%%',shadow=True,explode=explode,colors=['blue','green','yellow','pink','cyan'])
plt.show()

# %%
marks_sub=[]
for i in range(len(data)):
    sub=subjects[i]
    mark=str(data[i])
    det=sub+' : '+mark
    marks_sub.append(det)

# %%
plt.pie(data,labels=marks_sub,autopct='%0.1f%%',shadow=True,explode=explode,colors=['blue','green','yellow','pink','cyan'])
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('grayscale')

# %%
plt.pie(data,labels=marks_sub,autopct='%0.1f%%',shadow=True,explode=explode,colors=['blue','green','yellow','pink','cyan'])
plt.show()
