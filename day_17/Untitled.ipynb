# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### scatter plot

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',style='sex',hue='time',size='size')
plt.title('total bill vs tips')
plt.show()

# %%
tips['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex',row='day')

# %%
gap=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\gap.csv")

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
plt.figure(figsize=(10,3))
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=4)

# %% [markdown]
# ### Histogram

# %%
ages={23,45,56,34,23,34,25,45,37,29,22,43,56,67,34}
sns.histplot(ages,color='black',bins=5,edgecolor='red')
plt.grid()

# %% [markdown]
# ### Line plot

# %%
import pandas as pd

# %%
temp_df=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\gap_data.csv")

# %%
temp_df
# Out:
#     country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 0    Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 1    Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 2    Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 3    Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 4    Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 5    Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 6    Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 7    Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 8    Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 9    Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 10   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 11   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=temp_df,x='year',y='lifeExp',hue='country',style='continent',markers=['o','s','D'])
plt.xticks(temp_df['year'].unique().tolist())
plt.show()

# %%
temp_df['year'].unique().tolist()
# Out:
# [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007]
