# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\List of most-polluted cities by particulate matter concentration - List of most-polluted cities by particulate matter concentration.csv")

# %%
df
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# ...

# %% [markdown]
# # Problem-1: Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
df['Year']=df['Year'].astype(int)

# %%
temp_df=df[df['Country'].isin(['Iran','China'])]

# %%
temp_df.head(1)
# Out:
#     Unnamed: 0  Position Country City/Town  Year  PM2.5 Temporal coverage  \
# 18          18        19   China   Baoding  2016     93               NaN
#
#     PM10 Temporal coverage.1  Database version (year)
# 18   147                 NaN                     2018

# %%
pm25_sum=temp_df.groupby('Year')['PM2.5'].sum().reset_index()

# %%
pm25_sum
# Out:
#    Year  PM2.5
# 0  2012     37
# 1  2013     66
# 2  2014   2756
# 3  2015    425
# 4  2016  12559

# %%
plt.figure(figsize=(10,5))
plt.plot(pm25_sum['Year'],pm25_sum['PM2.5'],marker='*',color='purple')
plt.xticks(pm25_sum['Year'])
plt.xlabel('Year')
plt.ylabel('Sum of PM2.5')
plt.title('PM2.5 levels over years for Iran and China')
plt.grid()
plt.show()

# %% [markdown]
# # Problem-2: Draw a histogram of the column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
plt.figure(figsize=(10,5))
plt.hist(df['PM10'].dropna(),bins=30,density=True,alpha=0.7,color='green',edgecolor='black')
plt.xlabel('PM10')
plt.ylabel('Probability')
plt.title('Histogram of PM10 with Probability')
plt.grid()
plt.show()

# %% [markdown]
# # Problem-3: Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
poland=df[df['Country']=='Poland']
chile=df[df['Country']=='Chile']

# %%
plt.figure(figsize=(10,5))
plt.scatter(poland['PM2.5'],poland['PM10'],alpha=0.7,color='red',label='poland')
plt.scatter(chile['PM2.5'],chile['PM10'],alpha=0.7,color='green',label='chile')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('Scatter plot of PM2.5 and PM10 of Poland and Chile')
plt.legend(loc='upper center')
plt.grid()
plt.show()

# %% [markdown]
# # Problem-4: Draw a pie chart of top 5 most frequent countries

# %%
top=df['Country'].value_counts().sort_values(ascending=False).head(5)
explode=[0.01,0.2,0,0.2,0.3]

# %%
plt.pie(top,labels=top.index,autopct='%1.1f%%',shadow=True,explode=explode,colors=['pink', 'green', 'blue', 'purple', 'cyan'])
plt.show()

# %% [markdown]
# # Problem-5: Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
top.plot(kind='bar',color='pink')
plt.title('Top 5 most frequent countries')
plt.xlabel('Country')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sales=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\company_sales_data - company_sales_data.csv")

# %%
sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# # Problem-5 Show a line plot of Total Profit for each month with below styling.
# Dotted Line,
# Line Color Blue,
# Show Legend at top left,
# Circle Marker

# %%
plt.plot(sales['month_number'],sales['total_profit'],linestyle='dotted',color='blue',marker='o',label='Total Profit')
plt.title('Total profit per month')
plt.xticks(sales['month_number'])
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.legend(loc='upper left')

# %% [markdown]
# # Problem-6 Show sales of each product in march month as pie chart.
# Show Percentage value,Give Title "Sales in March",Explode ToothPaste with shadow

# %%
march=sales[sales['month_number']==3][['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']].sum()

# %% [raw]
# march

# %%
explode_values = [0, 0, 0.1, 0, 0, 0]
plt.pie(march, labels=march.index, autopct='%1.1f%%', explode=explode_values, shadow=True,colors=['red','green','yellow','blue','pink','purple'])
plt.title('Sales in March')
plt.show()

# %% [markdown]
# # Problem-7 Multiline Plot of all products sales,Give different styes for each products,Add legend at top right.

# %%
line_styles={
    'facecream':('solid','orange'),
    'facewash':('dashed','red'),
    'toothpaste':('dotted', 'green'),
    'bathingsoap':('dashdot','purple'),
    'shampoo':((0, (3, 1, 1, 1)),'blue'),
    'moisturizer':((0, (5, 2)),'brown')
}

# %%
plt.figure(figsize=(12,6))
for product,(style,color) in line_styles.items():
    plt.plot(sales['month_number'],sales[product],linestyle=style,color=color,marker='o',label=product)

plt.xlabel('Month Number')
plt.ylabel('Units Sold')
plt.title('Monthly Sales of All Products')    
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Problem-8 Show Quarter wise Sales data for all products as multi Bar chart.

# %%
sales['quarter'] = (sales['month_number'] - 1) // 3 + 1

# %%
quarterly_sales = sales.groupby('quarter')[['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']].sum()

# %%
quarterly_sales.plot(kind='bar', figsize=(10, 6),color=['blue','green','purple','pink','orange','brown'])
plt.xlabel('Quarter')
plt.ylabel('Total Units Sold')
plt.title('Quarterly Sales Data for All Products')
plt.legend(title='Products')
plt.show()

# %% [markdown]
# # Problem-9 Plot Stacked Bar chart quarter wise for each product
