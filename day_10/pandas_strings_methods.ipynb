# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
temp_df=df[['Name','Sex']]

# %%
temp_df
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %% [markdown]
# #### problem in vectorized operation in python

# %%
s=['cat','mat','rat']
[i.startswith('c') for i in s]
#tyo list ma None vako vaye error aauthyo
# Out:
# [True, False, False]

# %%
s=pd.Series(['cab','mat',None,'rat'])
s.str.startswith('c')
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %% [markdown]
# ### Common functions(lowe/upper/capitalize/title)

# %%
temp_df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')
temp_df['uppercase']=temp_df['Name'].str.upper()

# %%
temp_df
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                                              uppercase
# 0                              BRAUND, MR. OWEN HARRIS
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# ...

# %%
temp_df['lowercase']=temp_df['Name'].str.lower()

# %%
temp_df
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                                              lowercase
# 0                              braund, mr. owen harris
# 1    cumings, mrs. john bradley (florence briggs th...
# ...

# %%
temp_df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
temp_df['Name'].str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ### Fetch Mr and Mrs from dataset

# %% [markdown]
# #### split

# %%
temp_df['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
temp_df['Name'].str.split(',').str.get(0)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
temp_df['Gender_type']=temp_df['Name'].str.split(',').str.get(1).str.split('.').str.get(0)
temp_df
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                                              lowercase Gender_type
# 0                              braund, mr. owen harris          Mr
# 1    cumings, mrs. john bradley (florence briggs th...         Mrs
# ...

# %%
temp_df
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                                              lowercase Gender_type
# 0                              braund, mr. owen harris          Mr
# 1    cumings, mrs. john bradley (florence briggs th...         Mrs
# ...

# %%
temp_df['Gender_type'].value_counts()
# Out:
# Gender_type
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Col               2
# Mlle              2
# Major             2
# Ms                1
# Mme               1
# Don               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
temp_df['Gender_type']=temp_df['Gender_type'].str.replace('Ms','Miss')

# %%
temp_df
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                                              lowercase Gender_type
# 0                              braund, mr. owen harris          Mr
# 1    cumings, mrs. john bradley (florence briggs th...         Mrs
# ...

# %%
temp_df['Gender_type'].value_counts()
# Out:
# Gender_type
# Mr              517
# Miss            183
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# Don               1
# Mme               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
#swapcase()=viceversa of capital and small

# %% [markdown]
# ### Strip

# %%
s1='   hello world    '
print(s1)
print(len(s1)) #whitespace is counted
# Out:
#    hello world
# 18

# %%
clean_string=s1.strip() #removes white spaces
# Out:
# 'hello world'

# %%
len('clean_strings')
# Out:
# 13

# %%
temp_df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ### Starts with,ends with

# %%
temp_df['Name'].str.endswith('A')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
temp_df[temp_df['Name'].str.endswith('A')]
# Out:
#                       Name     Sex              lowercase Gender_type
# 64   Stewart, Mr. Albert A    male  stewart, mr. albert a          Mr
# 303    Keane, Miss. Nora A  female    keane, miss. nora a        Miss

# %%
temp_df[temp_df['Name'].str.contains('john',case=False)] #false rakhesi will not be case sensitive
# Out:
#                                                   Name     Sex  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female
# 45                            Rogers, Mr. William John    male
# 98                Doling, Mrs. John T (Ada Julia Bone)  female
# 112                             Barton, Mr. David John    male
# 117                    Turpin, Mr. William John Robert    male
# 160                           Cribb, Mr. John Hatfield    male
# 162                         Bengtsson, Mr. John Viktor    male
# 165    Goldsmith, Master. Frank John William "Frankie"    male
# 168                                Baumann, Mr. John D    male
# 172                       Johnson, Miss. Eleanor Ileen  female
# 188                                   Bourke, Mr. John    male
# 212                             Perkin, Mr. John Henry    male
# ...

# %%
temp_df['Name'].str[::-1]
# Out:
# 0                                sirraH newO .rM ,dnuarB
# 1      )reyahT sggirB ecnerolF( yeldarB nhoJ .srM ,sg...
# 2                                 aniaL .ssiM ,nenikkieH
# 3           )leeP yaM yliL( htaeH seuqcaJ .srM ,ellertuF
# 4                               yrneH mailliW .rM ,nellA
#                              ...
# 886                                sazouJ .veR ,alivtnoM
# 887                         htidE teragraM .ssiM ,maharG
# 888             "eirraC" neleH enirehtaC .ssiM ,notsnhoJ
# 889                                llewoH lraK .rM ,rheB
# 890                                  kcirtaP .rM ,yelooD
# Name: Name, Length: 891, dtype: object

# %%
temp_df['Sex']=temp_df['Sex'].str[0].str.upper()

# %%
temp_df
# Out:
#                                                   Name Sex  \
# 0                              Braund, Mr. Owen Harris   M
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   F
# 2                               Heikkinen, Miss. Laina   F
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   F
# 4                             Allen, Mr. William Henry   M
# ..                                                 ...  ..
# 886                              Montvila, Rev. Juozas   M
# 887                       Graham, Miss. Margaret Edith   F
# 888           Johnston, Miss. Catherine Helen "Carrie"   F
# 889                              Behr, Mr. Karl Howell   M
# 890                                Dooley, Mr. Patrick   M
#
#                                              lowercase Gender_type
# 0                              braund, mr. owen harris          Mr
# 1    cumings, mrs. john bradley (florence briggs th...         Mrs
# ...

# %% [markdown]
# ### date time split

# %%
import pandas as pd

# %%
data={
    'Start Time':['2025-02-01','2025-02-02','2025-02-03'],
    'End Time':['2025-02-02','2025-02-03','2025-02-04'],
    'Duration(Hours)':[5,8,6]
}
df=pd.DataFrame(data)
df
# Out:
#    Start Time    End Time  Duration(Hours)
# 0  2025-02-01  2025-02-02                5
# 1  2025-02-02  2025-02-03                8
# 2  2025-02-03  2025-02-04                6

# %%
df['Year']=df['Start Time'].str.split('-').str.get(0)

# %%
df['Month']=df['Start Time'].str.split('-').str.get(1)

# %%
df['Day']=df['Start Time'].str.split('-').str.get(2)

# %%
df
# Out:
#    Start Time    End Time  Duration(Hours)  Year Month Day
# 0  2025-02-01  2025-02-02                5  2025    02  01
# 1  2025-02-02  2025-02-03                8  2025    02  02
# 2  2025-02-03  2025-02-04                6  2025    02  03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Start Time       3 non-null      object
#  1   End Time         3 non-null      object
#  2   Duration(Hours)  3 non-null      int64
#  3   Year             3 non-null      object
#  4   Month            3 non-null      object
#  5   Day              3 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 276.0+ bytes

# %%
df['Year']=df['Year'].astype(int)

# %%
df['Month']=df['Month'].astype(int)

# %%
df['Day']=df['Day'].astype(int)

# %%
df
# Out:
#    Start Time    End Time  Duration(Hours)  Year  Month  Day
# 0  2025-02-01  2025-02-02                5  2025      2    1
# 1  2025-02-02  2025-02-03                8  2025      2    2
# 2  2025-02-03  2025-02-04                6  2025      2    3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Start Time       3 non-null      object
#  1   End Time         3 non-null      object
#  2   Duration(Hours)  3 non-null      int64
#  3   Year             3 non-null      int64
#  4   Month            3 non-null      int64
#  5   Day              3 non-null      int64
# dtypes: int64(4), object(2)
# memory usage: 276.0+ bytes

# %% [markdown]
# ### extract username and the domain name from the email

# %%
data={
    'Name':['Alice Johnson','Bob Smith','Charlie Brown','Diana Prince'],
    'Email':['alice.johnson@example.com','bob.smith@example.com','cahrlie.brown@example.com','diana.prince@example.com']
}
df=pd.DataFrame(data)
df
# Out:
#             Name                      Email
# 0  Alice Johnson  alice.johnson@example.com
# 1      Bob Smith      bob.smith@example.com
# 2  Charlie Brown  cahrlie.brown@example.com
# 3   Diana Prince   diana.prince@example.com

# %%
df['First Name']=df['Name'].str.split().str.get(0)

# %%
df
# Out:
#             Name                      Email First Name
# 0  Alice Johnson  alice.johnson@example.com      Alice
# 1      Bob Smith      bob.smith@example.com        Bob
# 2  Charlie Brown  cahrlie.brown@example.com    Charlie
# 3   Diana Prince   diana.prince@example.com      Diana

# %%
df['Last Name']=df['Name'].str.split().str.get(1)

# %%
df
# Out:
#             Name                      Email First Name Last Name
# 0  Alice Johnson  alice.johnson@example.com      Alice   Johnson
# 1      Bob Smith      bob.smith@example.com        Bob     Smith
# 2  Charlie Brown  cahrlie.brown@example.com    Charlie     Brown
# 3   Diana Prince   diana.prince@example.com      Diana    Prince

# %%
df['Username']=df['Email'].str.split('@').str.get(0)
df
# Out:
#             Name                      Email First Name Last Name  \
# 0  Alice Johnson  alice.johnson@example.com      Alice   Johnson
# 1      Bob Smith      bob.smith@example.com        Bob     Smith
# 2  Charlie Brown  cahrlie.brown@example.com    Charlie     Brown
# 3   Diana Prince   diana.prince@example.com      Diana    Prince
#
#         Username
# 0  alice.johnson
# 1      bob.smith
# 2  cahrlie.brown
# 3   diana.prince

# %%
df['Domain Name']=df['Email'].str.split('@').str.get(1)

# %%
df
# Out:
#             Name                      Email First Name Last Name  \
# 0  Alice Johnson  alice.johnson@example.com      Alice   Johnson
# 1      Bob Smith      bob.smith@example.com        Bob     Smith
# 2  Charlie Brown  cahrlie.brown@example.com    Charlie     Brown
# 3   Diana Prince   diana.prince@example.com      Diana    Prince
#
#         Username  Domain Name
# 0  alice.johnson  example.com
# 1      bob.smith  example.com
# 2  cahrlie.brown  example.com
# 3   diana.prince  example.com

# %%
df['Domain']=df['Domain Name'].str.split('.').str.get(1)

# %%
df
# Out:
#             Name                      Email First Name Last Name  \
# 0  Alice Johnson  alice.johnson@example.com      Alice   Johnson
# 1      Bob Smith      bob.smith@example.com        Bob     Smith
# 2  Charlie Brown  cahrlie.brown@example.com    Charlie     Brown
# 3   Diana Prince   diana.prince@example.com      Diana    Prince
#
#         Username  Domain Name Domain
# 0  alice.johnson  example.com    com
# 1      bob.smith  example.com    com
# 2  cahrlie.brown  example.com    com
# 3   diana.prince  example.com    com

# %%
df['Full Name']=df['First Name'] +' ' + df['Last Name']

# %%
df
# Out:
#             Name                      Email First Name Last Name  \
# 0  Alice Johnson  alice.johnson@example.com      Alice   Johnson
# 1      Bob Smith      bob.smith@example.com        Bob     Smith
# 2  Charlie Brown  cahrlie.brown@example.com    Charlie     Brown
# 3   Diana Prince   diana.prince@example.com      Diana    Prince
#
#         Username  Domain Name Domain      Full Name
# 0  alice.johnson  example.com    com  Alice Johnson
# 1      bob.smith  example.com    com      Bob Smith
# 2  cahrlie.brown  example.com    com  Charlie Brown
# 3   diana.prince  example.com    com   Diana Prince
