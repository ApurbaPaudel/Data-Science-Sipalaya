# %%
import pandas as pd

# %%
import numpy as np

# %%
date=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\messages\orders.csv")
time=pd.read_csv(r"C:\Users\DELL\Desktop\Sipalaya Data Science\datas\messages\messages.csv")

# %%
date
# Out:
#            date  product_id  city_id  orders
# 0    2019-12-10        5628       25       3
# 1    2018-08-15        3646       14     157
# 2    2018-10-23        1859       25       1
# 3    2019-08-17        7292       25       1
# 4    2019-01-06        4344       25       3
# ..          ...         ...      ...     ...
# 995  2018-10-08         255       13       1
# 996  2018-12-06        5521        7       1
# 997  2019-05-07         487       26      14
# 998  2019-03-03        1503       21       2
# 999  2019-10-15        6371        7      22
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Pandas Timestamp

# %%
pd.Timestamp('2023/1/5')
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
type(pd.Timestamp('2023/1/5'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
date
# Out:
#            date  product_id  city_id  orders
# 0    2019-12-10        5628       25       3
# 1    2018-08-15        3646       14     157
# 2    2018-10-23        1859       25       1
# 3    2019-08-17        7292       25       1
# 4    2019-01-06        4344       25       3
# ..          ...         ...      ...     ...
# 995  2018-10-08         255       13       1
# 996  2018-12-06        5521        7       1
# 997  2019-05-07         487       26      14
# 998  2019-03-03        1503       21       2
# 999  2019-10-15        6371        7      22
#
# [1000 rows x 4 columns]

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
pd.Timestamp('5th January 2025')
# Out:
# Timestamp('2025-01-05 00:00:00')

# %%
type(pd.Timestamp('5th January 2025'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
date['date']
# Out:
# 0      2019-12-10
# 1      2018-08-15
# 2      2018-10-23
# 3      2019-08-17
# 4      2019-01-06
#           ...
# 995    2018-10-08
# 996    2018-12-06
# 997    2019-05-07
# 998    2019-03-03
# 999    2019-10-15
# Name: date, Length: 1000, dtype: object

# %%
date['date']=pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# ### Different date time attributes

# %%
date['year']=date['date'].dt.year

# %%
date
# Out:
#           date  product_id  city_id  orders  year
# 0   2019-12-10        5628       25       3  2019
# 1   2018-08-15        3646       14     157  2018
# 2   2018-10-23        1859       25       1  2018
# 3   2019-08-17        7292       25       1  2019
# 4   2019-01-06        4344       25       3  2019
# ..         ...         ...      ...     ...   ...
# 995 2018-10-08         255       13       1  2018
# 996 2018-12-06        5521        7       1  2018
# 997 2019-05-07         487       26      14  2019
# 998 2019-03-03        1503       21       2  2019
# 999 2019-10-15        6371        7      22  2019
#
# [1000 rows x 5 columns]

# %%
date['month']=date['date'].dt.month

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month
# 0   2019-12-10        5628       25       3  2019     12
# 1   2018-08-15        3646       14     157  2018      8
# 2   2018-10-23        1859       25       1  2018     10
# 3   2019-08-17        7292       25       1  2019      8
# 4   2019-01-06        4344       25       3  2019      1
# ..         ...         ...      ...     ...   ...    ...
# 995 2018-10-08         255       13       1  2018     10
# 996 2018-12-06        5521        7       1  2018     12
# 997 2019-05-07         487       26      14  2019      5
# 998 2019-03-03        1503       21       2  2019      3
# 999 2019-10-15        6371        7      22  2019     10
#
# [1000 rows x 6 columns]

# %%
# month_name()
date['month_name']=date['date'].dt.month_name()

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month month_name
# 0   2019-12-10        5628       25       3  2019     12   December
# 1   2018-08-15        3646       14     157  2018      8     August
# 2   2018-10-23        1859       25       1  2018     10    October
# 3   2019-08-17        7292       25       1  2019      8     August
# 4   2019-01-06        4344       25       3  2019      1    January
# ..         ...         ...      ...     ...   ...    ...        ...
# 995 2018-10-08         255       13       1  2018     10    October
# 996 2018-12-06        5521        7       1  2018     12   December
# 997 2019-05-07         487       26      14  2019      5        May
# 998 2019-03-03        1503       21       2  2019      3      March
# 999 2019-10-15        6371        7      22  2019     10    October
#
# [1000 rows x 7 columns]

# %%
date['month_name'].str[:3]
# Out:
# 0      Dec
# 1      Aug
# 2      Oct
# 3      Aug
# 4      Jan
#       ...
# 995    Oct
# 996    Dec
# 997    May
# 998    Mar
# 999    Oct
# Name: month_name, Length: 1000, dtype: object

# %%
date['month_name']=date['date'].dt.month_name().str[0:3]

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month month_name
# 0   2019-12-10        5628       25       3  2019     12        Dec
# 1   2018-08-15        3646       14     157  2018      8        Aug
# 2   2018-10-23        1859       25       1  2018     10        Oct
# 3   2019-08-17        7292       25       1  2019      8        Aug
# 4   2019-01-06        4344       25       3  2019      1        Jan
# ..         ...         ...      ...     ...   ...    ...        ...
# 995 2018-10-08         255       13       1  2018     10        Oct
# 996 2018-12-06        5521        7       1  2018     12        Dec
# 997 2019-05-07         487       26      14  2019      5        May
# 998 2019-03-03        1503       21       2  2019      3        Mar
# 999 2019-10-15        6371        7      22  2019     10        Oct
#
# [1000 rows x 7 columns]

# %%
date['day']=date['date'].dt.day

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month month_name  day
# 0   2019-12-10        5628       25       3  2019     12        Dec   10
# 1   2018-08-15        3646       14     157  2018      8        Aug   15
# 2   2018-10-23        1859       25       1  2018     10        Oct   23
# 3   2019-08-17        7292       25       1  2019      8        Aug   17
# 4   2019-01-06        4344       25       3  2019      1        Jan    6
# ..         ...         ...      ...     ...   ...    ...        ...  ...
# 995 2018-10-08         255       13       1  2018     10        Oct    8
# 996 2018-12-06        5521        7       1  2018     12        Dec    6
# 997 2019-05-07         487       26      14  2019      5        May    7
# 998 2019-03-03        1503       21       2  2019      3        Mar    3
# 999 2019-10-15        6371        7      22  2019     10        Oct   15
#
# [1000 rows x 8 columns]

# %%
date['day_name']=date['date'].dt.day_name()

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month month_name  day  \
# 0   2019-12-10        5628       25       3  2019     12        Dec   10
# 1   2018-08-15        3646       14     157  2018      8        Aug   15
# 2   2018-10-23        1859       25       1  2018     10        Oct   23
# 3   2019-08-17        7292       25       1  2019      8        Aug   17
# 4   2019-01-06        4344       25       3  2019      1        Jan    6
# ..         ...         ...      ...     ...   ...    ...        ...  ...
# 995 2018-10-08         255       13       1  2018     10        Oct    8
# 996 2018-12-06        5521        7       1  2018     12        Dec    6
# 997 2019-05-07         487       26      14  2019      5        May    7
# 998 2019-03-03        1503       21       2  2019      3        Mar    3
# 999 2019-10-15        6371        7      22  2019     10        Oct   15
#
#       day_name
# 0      Tuesday
# 1    Wednesday
# 2      Tuesday
# 3     Saturday
# ...

# %%
#first(1,2,3)
#sec=(4,5,6)
#third=(7,8,9)
#fouth=(10,11,12)

# %%
date['quarter']=date['date'].dt.quarter

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month month_name  day  \
# 0   2019-12-10        5628       25       3  2019     12        Dec   10
# 1   2018-08-15        3646       14     157  2018      8        Aug   15
# 2   2018-10-23        1859       25       1  2018     10        Oct   23
# 3   2019-08-17        7292       25       1  2019      8        Aug   17
# 4   2019-01-06        4344       25       3  2019      1        Jan    6
# ..         ...         ...      ...     ...   ...    ...        ...  ...
# 995 2018-10-08         255       13       1  2018     10        Oct    8
# 996 2018-12-06        5521        7       1  2018     12        Dec    6
# 997 2019-05-07         487       26      14  2019      5        May    7
# 998 2019-03-03        1503       21       2  2019      3        Mar    3
# 999 2019-10-15        6371        7      22  2019     10        Oct   15
#
#       day_name  quarter
# 0      Tuesday        4
# 1    Wednesday        3
# ...

# %%
# 1-6=first sem
# 7 to 12=sec sem

# %%
date['quarter']
# Out:
# 0      4
# 1      3
# 2      4
# 3      3
# 4      1
#       ..
# 995    4
# 996    4
# 997    2
# 998    1
# 999    4
# Name: quarter, Length: 1000, dtype: int32

# %%
date['quarter'].isin([1,2])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name: quarter, Length: 1000, dtype: bool

# %%
date['semester']=np.where(date['quarter'].isin([1,2]),'First','Second')

# %%
 date
# Out:
#           date  product_id  city_id  orders  year  month month_name  day  \
# 0   2019-12-10        5628       25       3  2019     12        Dec   10
# 1   2018-08-15        3646       14     157  2018      8        Aug   15
# 2   2018-10-23        1859       25       1  2018     10        Oct   23
# 3   2019-08-17        7292       25       1  2019      8        Aug   17
# 4   2019-01-06        4344       25       3  2019      1        Jan    6
# ..         ...         ...      ...     ...   ...    ...        ...  ...
# 995 2018-10-08         255       13       1  2018     10        Oct    8
# 996 2018-12-06        5521        7       1  2018     12        Dec    6
# 997 2019-05-07         487       26      14  2019      5        May    7
# 998 2019-03-03        1503       21       2  2019      3        Mar    3
# 999 2019-10-15        6371        7      22  2019     10        Oct   15
#
#       day_name  quarter semester
# 0      Tuesday        4   Second
# ...

# %%
time
# Out:
#                     date                                                msg
# 0    2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1    2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2    2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3    2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4    2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                   ...                                                ...
# 995  2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996  2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997  2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998  2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999  2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
# [1000 rows x 2 columns]

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time['date']=pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['date']
# Out:
# 0     2013-12-15 00:50:00
# 1     2014-04-29 23:40:00
# 2     2012-12-30 00:21:00
# 3     2014-11-28 00:31:00
# 4     2013-10-26 23:11:00
#               ...
# 995   2012-03-16 00:50:00
# 996   2014-01-23 23:14:00
# 997   2012-10-15 23:37:00
# 998   2012-06-21 23:34:00
# 999   2014-06-19 23:25:00
# Name: date, Length: 1000, dtype: datetime64[ns]

# %%
time['hour']=time['date'].dt.hour

# %%
time
# Out:
#                    date                                                msg  \
# 0   2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1   2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2   2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3   2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4   2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                  ...                                                ...
# 995 2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996 2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997 2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998 2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999 2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
#      hour
# 0       0
# 1      23
# 2       0
# 3       0
# ...

# %%
time['minute']=time['date'].dt.minute

# %%
time
# Out:
#                    date                                                msg  \
# 0   2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1   2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2   2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3   2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4   2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                  ...                                                ...
# 995 2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996 2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997 2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998 2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999 2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
#      hour  minute
# 0       0      50
# 1      23      40
# ...

# %%
time['seconds']=time['date'].dt.second

# %%
time
# Out:
#                    date                                                msg  \
# 0   2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1   2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2   2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3   2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4   2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                  ...                                                ...
# 995 2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996 2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997 2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998 2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999 2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
#      hour  minute  seconds
# 0       0      50        0
# ...

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month month_name  day  \
# 0   2019-12-10        5628       25       3  2019     12        Dec   10
# 1   2018-08-15        3646       14     157  2018      8        Aug   15
# 2   2018-10-23        1859       25       1  2018     10        Oct   23
# 3   2019-08-17        7292       25       1  2019      8        Aug   17
# 4   2019-01-06        4344       25       3  2019      1        Jan    6
# ..         ...         ...      ...     ...   ...    ...        ...  ...
# 995 2018-10-08         255       13       1  2018     10        Oct    8
# 996 2018-12-06        5521        7       1  2018     12        Dec    6
# 997 2019-05-07         487       26      14  2019      5        May    7
# 998 2019-03-03        1503       21       2  2019      3        Mar    3
# 999 2019-10-15        6371        7      22  2019     10        Oct   15
#
#       day_name  quarter semester
# 0      Tuesday        4   Second
# ...

# %%
date['date']
# Out:
# 0     2019-12-10
# 1     2018-08-15
# 2     2018-10-23
# 3     2019-08-17
# 4     2019-01-06
#          ...
# 995   2018-10-08
# 996   2018-12-06
# 997   2019-05-07
# 998   2019-03-03
# 999   2019-10-15
# Name: date, Length: 1000, dtype: datetime64[ns]

# %%
date['strformart']=date['date'].dt.strftime('%d %B , %Y')

# %%
date
# Out:
#           date  product_id  city_id  orders  year  month month_name  day  \
# 0   2019-12-10        5628       25       3  2019     12        Dec   10
# 1   2018-08-15        3646       14     157  2018      8        Aug   15
# 2   2018-10-23        1859       25       1  2018     10        Oct   23
# 3   2019-08-17        7292       25       1  2019      8        Aug   17
# 4   2019-01-06        4344       25       3  2019      1        Jan    6
# ..         ...         ...      ...     ...   ...    ...        ...  ...
# 995 2018-10-08         255       13       1  2018     10        Oct    8
# 996 2018-12-06        5521        7       1  2018     12        Dec    6
# 997 2019-05-07         487       26      14  2019      5        May    7
# 998 2019-03-03        1503       21       2  2019      3        Mar    3
# 999 2019-10-15        6371        7      22  2019     10        Oct   15
#
#       day_name  quarter semester          strformart
# ...

# %% [markdown]
# ### errors='coerce'

# %%
date_list=['2025-02-27','invalid','2025-03-05','2025-56-12']
pd.to_datetime(date_list,errors='coerce')
# Out:
# DatetimeIndex(['2025-02-27', 'NaT', '2025-03-05', 'NaT'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### date

# %%
pd.to_datetime('now')
# Out:
# Timestamp('2025-03-09 20:30:30.794635')

# %%
pd.to_datetime('now')-date['date']
# Out:
# 0     1916 days 20:31:51.381881
# 1     2398 days 20:31:51.381881
# 2     2329 days 20:31:51.381881
# 3     2031 days 20:31:51.381881
# 4     2254 days 20:31:51.381881
#                  ...
# 995   2344 days 20:31:51.381881
# 996   2285 days 20:31:51.381881
# 997   2133 days 20:31:51.381881
# 998   2198 days 20:31:51.381881
# 999   1972 days 20:31:51.381881
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
date['dayss']=pd.to_datetime('now')-date['date']

# %%
date['dayss'].astype(str).str.split(' ').str.get(0)
# Out:
# 0      1916
# 1      2398
# 2      2329
# 3      2031
# 4      2254
#        ...
# 995    2344
# 996    2285
# 997    2133
# 998    2198
# 999    1972
# Name: dayss, Length: 1000, dtype: object

# %% [markdown]
# ### dataset creation

# %%
today=np.array('2015-07-04',dtype=np.datetime64)

# %%
subscriber=np.random.randint(1,20,1000)

# %%
subscriber
# Out:
# array([ 4, 11,  6, 12, 12,  2, 10,  6, 19, 16, 15,  4,  9,  1,  8,  8,  2,
#        17, 14,  8,  4,  4,  3,  3,  5,  4, 10,  2,  2, 19,  6,  2,  3, 12,
#         1,  9, 18,  7, 13, 10, 14,  5, 10,  1,  2,  3,  2,  7, 14, 11,  1,
#         5,  4,  6, 13, 18,  9, 16,  3, 11,  7, 11, 12,  1,  1,  2,  4, 18,
#         1, 18,  2, 15,  4, 12, 12,  7,  9,  7, 16,  9, 19,  7, 19,  4,  4,
#         8, 12,  1,  6,  2,  8,  4,  5, 11,  6,  4,  1,  2, 17, 13, 15,  7,
#         6, 12,  6, 10,  3, 16,  6, 15, 12,  4, 17, 11,  6, 16, 11,  9, 17,
#        17, 13,  3, 10,  3, 14,  5, 12, 14, 13,  5,  9,  9, 15, 11, 15, 11,
#        12,  8,  7,  5,  2, 11, 18, 12,  1, 14,  5, 19,  3,  9,  6,  5,  7,
#         2, 11, 10,  1, 13, 15, 11,  3,  1,  9, 15,  3, 17,  5, 11,  6,  5,
#        17, 18,  7,  4, 17,  1, 19,  9,  9,  5, 11,  6,  6, 18, 18,  4, 10,
#        13, 12, 18,  2,  2,  1, 14,  7, 14, 16, 13,  8,  6,  4,  2,  8, 19,
# ...

# %%
dates=today+np.arange(1000)
dates[:5]
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08'], dtype='datetime64[D]')

# %%
df=pd.DataFrame({'date':dates,'subscriber':subscriber})

# %%
df
# Out:
#           date  subscriber
# 0   2015-07-04           4
# 1   2015-07-05          11
# 2   2015-07-06           6
# 3   2015-07-07          12
# 4   2015-07-08          12
# ..         ...         ...
# 995 2018-03-25          11
# 996 2018-03-26          18
# 997 2018-03-27          11
# 998 2018-03-28          16
# 999 2018-03-29          19
#
# [1000 rows x 2 columns]
